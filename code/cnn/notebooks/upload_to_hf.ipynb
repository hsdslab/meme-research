# %%
import pytorch_lightning as pl
from thresholded_model import BinaryMemeClassifier
from model import ImagenetTransferLearning
from model import CombinedMemeClassifier

binary_model = BinaryMemeClassifier.load_from_checkpoint("/home/hsdslab/murgi/meme-research-2024/src/models/best/binary_densenet121epoch=01-val_loss=0.00.ckpt")
template_model = ImagenetTransferLearning.load_from_checkpoint("/home/hsdslab/murgi/meme-research-2024/src/models/best/multi_densenet121epoch=09-val_loss=0.00.ckpt")

combined_model = CombinedMemeClassifier(binary_model, template_model)
print(combined_model.best_threshold)
# Out:
# 0.999

# %% [markdown]
# ## Multi model

# %% [markdown]
# Upload

# %%
template_model.push_to_hub('HSDSLab/MemeTemplateClassifier')
# Out:
# model.safetensors:   0%|          | 0.00/258M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/HSDSLab/MemeTemplateClassifier/commit/5475b8bd7f607cbe6dd25c32c8aac319c0be507f', commit_message='Push model using huggingface_hub.', commit_description='', oid='5475b8bd7f607cbe6dd25c32c8aac319c0be507f', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# Load

# %%
loaded_model = ImagenetTransferLearning.from_pretrained('HSDSLab/MemeTemplateClassifier')
loaded_model
# Out:
# config.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/258M [00:00<?, ?B/s]
# ImagenetTransferLearning(
#   (criterion): CrossEntropyLoss()
#   (train_accuracy): MulticlassAccuracy()
#   (val_accuracy): MulticlassAccuracy()
#   (mcc): MulticlassMatthewsCorrCoef()
#   (kappa): MulticlassCohenKappa()
#   (f1): MulticlassF1Score()
#   (feature_extractor): Sequential(
#     (0): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
# ...

# %% [markdown]
# ## Binary model

# %% [markdown]
# Upload

# %%
binary_model.push_to_hub('HSDSLab/BinaryMemeClassifier')
# Out:
# model.safetensors:   0%|          | 0.00/28.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/HSDSLab/BinaryMemeClassifier/commit/229d32a3b8cf970ab59d91119cb5a837755bbcfe', commit_message='Push model using huggingface_hub.', commit_description='', oid='229d32a3b8cf970ab59d91119cb5a837755bbcfe', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# Load

# %%
loaded_binary = BinaryMemeClassifier.from_pretrained('HSDSLab/BinaryMemeClassifier')
loaded_binary
# Out:
# config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/28.4M [00:00<?, ?B/s]
# BinaryMemeClassifier(
#   (criterion): BCELoss()
#   (train_accuracy): BinaryAccuracy()
#   (val_accuracy): BinaryAccuracy()
#   (mcc): BinaryMatthewsCorrCoef()
#   (kappa): BinaryCohenKappa()
#   (f1): BinaryF1Score()
#   (feature_extractor): Sequential(
#     (0): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
# ...

# %% [markdown]
# ## Combined model

# %%
combined_model = CombinedMemeClassifier(loaded_binary, loaded_model)
combined_model
# Out:
# CombinedMemeClassifier(
#   (binary_classifier): BinaryMemeClassifier(
#     (criterion): BCELoss()
#     (train_accuracy): BinaryAccuracy()
#     (val_accuracy): BinaryAccuracy()
#     (mcc): BinaryMatthewsCorrCoef()
#     (kappa): BinaryCohenKappa()
#     (f1): BinaryF1Score()
#     (feature_extractor): Sequential(
#       (0): Sequential(
#         (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu0): ReLU(inplace=True)
#         (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (denseblock1): _DenseBlock(
#           (denselayer1): _DenseLayer(
#             (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu1): ReLU(inplace=True)
#             (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...
